# %%
import matplotlib.pyplot as plt
from scipy import stats 
import pandas as pd
import numpy as np

# %%
x = []
with open("x.txt") as f:
    strings = f.readlines()
    for string in strings:
        x.append(float(string))

# %%
y = []
with open("y.txt") as f:
    strings = f.readlines()
    for string in strings:
        y.append(float(string))

# %%
plt.plot(x,y)
plt.grid()

# %%
x = []
with open("x.txt") as f:
    strings = f.readlines()
    for string in strings:
        x.append(float(string))

# %%
y1 = []
with open("y.txt") as f:
    strings = f.readlines()
    for string in strings:
        y1.append(float(string))

# %%
y2 = []
with open("y.txt") as f:
    strings = f.readlines()
    for string in strings:
        y2.append(float(string))

# %%
y3 = []
with open("y.txt") as f:
    strings = f.readlines()
    for string in strings:
        y3.append(float(string))

# %%
y4 = []
with open("y.txt") as f:
    strings = f.readlines()
    for string in strings:
        y4.append(float(string))

# %%
y5 = []
with open("y.txt") as f:
    strings = f.readlines()
    for string in strings:
        y5.append(float(string))

# %%
y6 = []
with open("y.txt") as f:
    strings = f.readlines()
    for string in strings:
        y6.append(float(string))

# %%
plt.plot(x,y1, label="b = 0")
plt.plot(x,y2, label="b = 0.2")
plt.plot(x,y3, label="b = 0.4")
plt.plot(x,y4, label="b = 0.6")
plt.plot(x,y5, label="b = 0.8")
plt.plot(x,y6, label="b = 1")
plt.legend()
plt.grid()
#plt.savefig("function.png")

# %%
def confidenceInterval (serviceTimes, alpha = 0.01):
  n = len(serviceTimes)
  return np.sqrt(np.var(serviceTimes, ddof=1)) / np.sqrt(n) * stats.t.ppf(1-alpha/2, n-1)

# %%
exp3 = pd.read_csv("results.txt", sep='\t', index_col = None, header = 0)

# %%
exp3.head()
# Out:
#    Num      Time
# 0    1  0.002522
# 1    2  0.002281
# 2    3  0.011885
# 3    4  0.015998
# 4    5  0.017856

# %%
gr3 = exp3.groupby(['Num'])['Time'].agg([np.mean, confidenceInterval]).reset_index()

# %%
gr3.head()
# Out:
#    Num      mean  confidenceInterval
# 0    1  0.004146            0.001070
# 1    2  0.017169            0.001971
# 2    3  0.015947            0.002273
# 3    4  0.016504            0.001479
# 4    5  0.013327            0.001753

# %%
plt.errorbar(gr3['Num'], gr3['mean'], gr3['confidenceInterval'], \
             marker = 'x', linestyle = '-', color = 'b')

plt.xlabel(r'Threads num')
plt.ylabel('Time, sec')
plt.grid()
#plt.savefig("time.png")
